# %%
import pandas
from bokeh.plotting import figure, output_file, show

# %%
df=pandas.DataFrame(columns=["X", "Y"])

# %%
df["X"]=[1,2,3,4,5]
df["Y"]=[4,3,5,1,2]

# %%
p=figure(plot_width=500, plot_height=400, title="Earthquakes", xlabe="Day of Observation", ylabel="Intensity")

# %%
p.circle([1,2,3,4,5], [3,5,2,4,1], size=[i*2 for i in [2,6,10,15,20]], color="red", alpha=5)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='835f44ad-a75d-44ea-aeb7-1d83920b6111',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='a7de2a84-4a09-4cd8-b981-924d63a2f434',
#         callback=None,
#         data={'size': [4, 12, 20, 30, 40],
#          'x': [1, 2, 3, 4, 5],
#          'y': [3, 5, 2, 4, 1]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='45b4ced2-d824-4563-8341-4886fce7c165',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='c871d14b-4265-4fc4-951c-89f5545d2bce',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='7c8556c2-4366-4d72-aad3-2caf1b4feca2',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 5},
#         fill_color={'value': 'red'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 5},
#         line_cap='butt',
#         line_color={'value': 'red'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'field': 'size', 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='b13d1f63-b212-46b7-8d75-c57640cb6b47',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'field': 'size', 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='7aab2725-2722-4a7c-b3f6-0643bab468cb',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='a7de2a84-4a09-4cd8-b981-924d63a2f434',
#             callback=None,
#             data={'size': [4, 12, 20, 30, 40],
#              'x': [1, 2, 3, 4, 5],
#              'y': [3, 5, 2, 4, 1]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='45b4ced2-d824-4563-8341-4886fce7c165',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='c871d14b-4265-4fc4-951c-89f5545d2bce',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
output_file("Scatter_Plotting.html")
show(p)

# %%
df1=pandas.DataFrame(columns=["A", "B"])

df2=pandas.DataFrame(columns=["C", "D"])

df3=pandas.DataFrame(columns=["E", "F"])

df4=pandas.DataFrame(columns=["G", "H"])


df5=pandas.DataFrame(columns=["I", "J"])

df6=pandas.DataFrame(columns=["K", "L"])


df7=pandas.DataFrame(columns=["M", "N"])

df8=pandas.DataFrame(columns=["O", "P"])

df9=pandas.DataFrame(columns=["Q", "R"])


df10=pandas.DataFrame(columns=["S", "T"])
